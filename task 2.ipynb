# %%
pip install folium
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: folium in c:\users\sweet\anaconda3\lib\site-packages (0.19.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\sweet\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sweet\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\sweet\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\sweet\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\sweet\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sweet\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sweet\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sweet\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sweet\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sweet\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import folium
from folium.plugins import MarkerCluster

# %%
import folium

# Sample merged data
mergedata = [
    {"name": "Spice Hub", "location": [17.3850, 78.4867], "cuisine": "Indian"},
    {"name": "Dragon Wok", "location": [17.3852, 78.4869], "cuisine": "Chinese"},
    {"name": "Pizza Palace", "location": [17.3855, 78.4872], "cuisine": "Italian"},
    {"name": "Curry Leaf", "location": [17.3858, 78.4875], "cuisine": "Indian"},
]

# Create the folium map
mymap = folium.Map(location=[17.3850, 78.4867], zoom_start=13)

# Define colors for each cuisine
colors = {
    "Indian": "red",
    "Chinese": "blue",
    "Italian": "green"
}

# Add markers to the map
for place in mergedata:
    folium.Marker(
        location=place["location"],
        popup=f"{place['name']} ({place['cuisine']})",
        icon=folium.Icon(color=colors.get(place["cuisine"], "gray"))
    ).add_to(mymap)

# Display the map in Jupyter Notebook
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd1dce26aafcf0486c9334f3f39ea36e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd1dce26aafcf0486c9334f3f39ea36e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd1dce26aafcf0486c9334f3f39ea36e = L.map(
#                 &quot;map_cd1dce26aafcf0486c9334f3f39ea36e&quot;,
#                 {
#                     center: [17.385, 78.4867],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29418c82b731b862c643ff702a321878 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29418c82b731b862c643ff702a321878.addTo(map_cd1dce26aafcf0486c9334f3f39ea36e);
#
#
#             var marker_d99830719e7cfa00ee73c421d0c533bf = L.marker(
#                 [17.385, 78.4867],
#                 {
# }
#             ).addTo(map_cd1dce26aafcf0486c9334f3f39ea36e);
#
#
#             var icon_76dbb21519563f2058a240fc281cdbcb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b8172fa10e409830bf9cd60a0cef5f03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b3e2dc845aeae4f71790c8f67fb53ee = $(`&lt;div id=&quot;html_9b3e2dc845aeae4f71790c8f67fb53ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Spice Hub (Indian)&lt;/div&gt;`)[0];
#                 popup_b8172fa10e409830bf9cd60a0cef5f03.setContent(html_9b3e2dc845aeae4f71790c8f67fb53ee);
#
#
#
#         marker_d99830719e7cfa00ee73c421d0c533bf.bindPopup(popup_b8172fa10e409830bf9cd60a0cef5f03)
#         ;
#
#
#
#
#                 marker_d99830719e7cfa00ee73c421d0c533bf.setIcon(icon_76dbb21519563f2058a240fc281cdbcb);
#
#
#             var marker_8370d9c607be420ecd3cf30eb6a9d424 = L.marker(
#                 [17.3852, 78.4869],
#                 {
# }
#             ).addTo(map_cd1dce26aafcf0486c9334f3f39ea36e);
#
#
#             var icon_2bb2496b2cda50fc87fbba72f94d8c42 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cf572c4007f88ea5c642e896c90e768e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab4aeea8ae80d0c2ffa49183b816d036 = $(`&lt;div id=&quot;html_ab4aeea8ae80d0c2ffa49183b816d036&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dragon Wok (Chinese)&lt;/div&gt;`)[0];
#                 popup_cf572c4007f88ea5c642e896c90e768e.setContent(html_ab4aeea8ae80d0c2ffa49183b816d036);
#
#
#
#         marker_8370d9c607be420ecd3cf30eb6a9d424.bindPopup(popup_cf572c4007f88ea5c642e896c90e768e)
#         ;
#
#
#
#
#                 marker_8370d9c607be420ecd3cf30eb6a9d424.setIcon(icon_2bb2496b2cda50fc87fbba72f94d8c42);
#
#
#             var marker_fe8465953b8b76b578a978d556e5c585 = L.marker(
#                 [17.3855, 78.4872],
#                 {
# }
#             ).addTo(map_cd1dce26aafcf0486c9334f3f39ea36e);
#
#
#             var icon_ce8ef4f621f93d51553f6ed9a8309713 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_87147e6cbd851a8647fd97abf9ce088b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef4f77a44ca104921d1302ed05225147 = $(`&lt;div id=&quot;html_ef4f77a44ca104921d1302ed05225147&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pizza Palace (Italian)&lt;/div&gt;`)[0];
#                 popup_87147e6cbd851a8647fd97abf9ce088b.setContent(html_ef4f77a44ca104921d1302ed05225147);
#
#
#
#         marker_fe8465953b8b76b578a978d556e5c585.bindPopup(popup_87147e6cbd851a8647fd97abf9ce088b)
#         ;
#
#
#
#
#                 marker_fe8465953b8b76b578a978d556e5c585.setIcon(icon_ce8ef4f621f93d51553f6ed9a8309713);
#
#
#             var marker_891e51a60af3319227458b14d62acfdd = L.marker(
#                 [17.3858, 78.4875],
#                 {
# }
#             ).addTo(map_cd1dce26aafcf0486c9334f3f39ea36e);
#
#
#             var icon_10964d0580280ce38b264694d22ba0fc = L.AwesomeMarkers.icon(
